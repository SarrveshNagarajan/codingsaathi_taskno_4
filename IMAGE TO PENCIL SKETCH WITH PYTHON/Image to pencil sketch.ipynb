# %%
# !pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\nsarr\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nsarr\anaconda3\lib\site-packages (from opencv-contrib-python) (1.22.4)
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
image = cv2.imread('lion.jpg')
cv2.imshow('Lion',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2.imshow("New Lion", gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
inverted_image = 255 - gray_image
cv2.imshow("Inverted", inverted_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
blur = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blur
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("original image", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
cv2.destroyAllWindows()
